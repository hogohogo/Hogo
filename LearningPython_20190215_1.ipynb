# %% [markdown]
# # Class Two

# %% [markdown]
# ## Matrix Calculation

# %%
import numpy as np
A=np.array([1,2,3])
B=np.array([4,3,0])
print('A+B=',np.add(A,B))
print('A-B=',np.subtract(A,B))
# Out:
# A+B= [5 5 3]
# A-B= [-3 -1  3]

# %%
C=np.array([[1,2,3],[1,1,1]])
D=np.array([[4,3,9,9],[1,1,2,2],[4,2,1,1]]          )
print('np.dot(C,D)=',np.dot(C,D))
print('np.matmul(C,D)=',np.matmul(C,D))
print('C@D=',np.matmul(C,D))
print('np.multiply(D,D)=',np.multiply(D,D))
print('D*D=',D*D)
# Out:
# np.dot(C,D)= [[18 11 16 16]
#  [ 9  6 12 12]]
# np.matmul(C,D)= [[18 11 16 16]
#  [ 9  6 12 12]]
# C@D= [[18 11 16 16]
#  [ 9  6 12 12]]
# np.multiply(D,D)= [[16  9 81 81]
#  [ 1  1  4  4]
#  [16  4  1  1]]
# D*D= [[16  9 81 81]
#  [ 1  1  4  4]
#  [16  4  1  1]]

# %%
import sklearn

# %% [markdown]
# conda create -n Python3.5 python=3.5

# %% [markdown]
# activate Python3.5

# %% [markdown]
# pip install tensorflow

# %%
import tensorflow as tf

# %% [markdown]
# ## Markdown

# %% [markdown]
# ### Format

# %% [markdown]
# **BoldFont**

# %% [markdown]
# *Italic*

# %% [markdown]
# * item

# %% [markdown]
# 1. item1
# 4. item2
# 7. item3

# %% [markdown]
# 3. item1
# 7. item2

# %% [markdown]
# > Cite

# %% [markdown]
# Latex Formula

# %% [markdown]
# $e^{i\pi}+1=0$

# %% [markdown]
# $\sum_{\forall i}{x_i^{2}}$

# %% [markdown]
# $\sum_{i=1}^{i=n}$

# %% [markdown]
# ### Insert Pic

# %% [markdown]
# <img src='D:/PPT Template/Wallpaper/timg.jpg'>

# %%
from IPython.display import Image

# %%
Image(filename='D:/PPT Template/Wallpaper/timg.jpg', width=200)

# %% [markdown]
# ### Insert Table

# %% [markdown]
# |Column1   |Column2    |Column3    |
# |-  |:-----:|  -|
# |Name| Age| Number|
